# %% [markdown]
# # Variables

# %% [markdown]
# Just like the familiar variable $x$ and $y$ in mathematics, we use variables in programming to easily manipulate values. The assignment operator `=` assigns values to variables in Python. Choose descriptive variable names and avoid special Python reserved words.

# %% [markdown]
# ## Assign Values to Variables

# %% [markdown]
# Assign a value to a variable using the assignment operator `=`.
# For example, assign the integer 2 to the variable `x`:

# %%
x = 2

# %% [markdown]
# The assignment operator does not produce any output and so the cell above not produce any output in a Jupyter Notebook. Use the built-in function `print` to display the value assigned to a variable

# %%
print(x)
# Out:
# 2

# %% [markdown]
# Compute new values using variables and operators:

# %%
1 + x +x**2 + x**3
# Out:
# 15

# %% [markdown]
# Use the bulit-in function `type` to verify the datatype of the value assigned to a variable

# %%
pi = 3.14159
type (pi)
# Out:
# float

# %% [markdown]
# ## Naming Conventions

# %% [markdown]
# We can use any set of letters, numbers and underscores to make variable names however a variable name cannot begin with a number. There are many different kinds of naming conventions and we refer to the [Style Guide for Python Code (PEP8)](https://www.python.org/dev/peps/pep-0008/#naming-conventions) for a summary.
#
# In this book we use `lower_case_with_underscores` variable names and single lowercase letter variable names such as `x`. It is good practice to use descriptive variable names to make your code more readable for other people.
#
# For example, the distance from Vancouver to Halifax along the Trans-Canada Highway is approximately 5779 kilometers. We write the following code to convert this value to miles:

# %%
distance_km = 5799
miles_per_km = 0.6214
distance_miles = distance_km * miles_per_km
print (distance_miles)
# Out:
# 3603.4986

# %% [markdown]
# ## Names to Avoid

# %% [markdown]
# It is good practice to use variable names which describe the value assigned to it. However there are words that we should not use as variable names because these words already special meaning in Python.

# %% [markdown]
# ### Reserved Words

# %%
Summarized below are the [reserved words in Python 3](https://docs.python.org/3.3/reference/lexical_analysis.html#keywords). Python will raise an error if you try to assign a value to any of these keywords and so you must avoid these as variable names.

# %% [markdown]
# |  |  |  |  |  |
# |:--:|:--:|:--:|:--:|:--:|
# | `False` | `class` | `finally` | `is` | `return` |
# | `none` | `continue` | `for` | `lambda` | `try` |
# | `True` | `def` | `from` | `nonlocal` | `while` |
# | `and` | `del` | `global` | `not` | `with` |
# | `as` | `elif` | `if` | `or` | `yield` |
# | `assert` | `else` | `import` | `pass` | `break` |
# | `except` | `in` | `raise` |  |  |

# %% [markdown]
# ### Built-in Function Names

# %% [markdown]
# There are several functions which are included in the standard Pyhton library. Do *not* use the names of these functions as variable names otherwise thereference to the built-in function will be lost. For example, do not use `sum`, `min`, `max`, `list` or `sorted` as a variable name. See the full list of [builtin functions](https://docs.python.org/3/library/functions.html).

# %% [markdown]
# ## Jupyter Magic: whos

# %% [markdown]
# The Jupyter magic command whos list all variables in the current Jupyter notebook and their types:

# %%
x = 2
pi = 3.14159
distance_per_km = 5799
miles_per_km = 0.6214
distance_miles = distance_km * miles_per_km

# %%
whos
# Out:
# Variable          Type     Data/Info
# ------------------------------------
# distance_km       int      5799
# distance_miles    float    3603.4986
# distance_per_km   int      5799
# miles_per_km      float    0.6214
# pi                float    3.14159
# x                 int      2

# %% [markdown]
# ## Exercise

# %% [markdown]
# **Exercise 1**. True or false: Python does not allowing assigning a value to variable name which is already a builtin Python function such as `sum`, `min`, `max`.

# %% [markdown]
# **True**
